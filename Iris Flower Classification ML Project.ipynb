# %% [markdown]
# # ----Let's Grow more - Data Science Internship----

# %% [markdown]
# # Task - 1
# **Iris Flower Classifiation**
#
# **----sweta pandey----**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings('ignore')

# %%
flower=pd.read_csv('C:\\machine Learning\\dataset\\IRIS.csv')
flower
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
flower.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
flower.shape
# Out:
# (150, 5)

# %%
flower.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
flower.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
flower.describe
# Out:
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
flower.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
flower.groupby('species').size()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# # Visulization
# **Checking for Outleirs**

# %%
fig, ax=plt.subplots(figsize=(15,10))
sns.boxplot(data=flower, width=0.5,ax=ax,fliersize=3)
# Out:
# <AxesSubplot:>

# %%
fig, ax=plt.subplots(figsize=(5,5))
sns.boxplot(data=flower['sepal_width'],width=0.5,ax=ax, fliersize=3)
# Out:
# <AxesSubplot:>

# %% [markdown]
#  ***Some outliers in the Sepal Width column***

# %% [markdown]
# # Plotting

# %%
sns.pairplot(data=flower , hue='species')
plt.show()

# %% [markdown]
# # Correlation

# %%
flower.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
plt.subplots(figsize=(8,7))
sns.heatmap(flower.corr(),annot=True,fmt='f').set_title("Corelation of attriues among Iris Species")
plt.show()

# %% [markdown]
# ***from the heatmap, it is observed that the petal length and with are highly correlated.***

# %% [markdown]
# # Data Comparision using Barplot

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.barplot(x='species',y='petal_length',data=flower)
plt.subplot(2,2,2)
sns.barplot(x='species',y='petal_length',data=flower)
plt.subplot(2,2,3)
sns.barplot(x='species',y='petal_width',data=flower)
plt.subplot(2,2,4)
sns.barplot(x='species',y='petal_width',data=flower)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %% [markdown]
# # scatter plot of sepal length and sepal width

# %%
setosa=flower[flower['species']=='Iris-setosa']
versicolor=flower[flower['species']=='Iris-versicolor']
virginica=flower[flower['species']=='Iris-virginica']

plt.figure(figsize=(10,10))
plt.scatter(setosa['sepal_length'],setosa['sepal_width'],c='blue',label='Iris-setosa',marker='*')
plt.scatter(versicolor['sepal_length'],versicolor['sepal_width'],c='red',label='versicolor',marker='^')
plt.scatter(virginica['sepal_length'],virginica['sepal_width'],c='green',label='veirginica',marker='<')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.title('sepal length vs sepal width',fontsize=15)
plt.legend()
plt.show()

# %% [markdown]
# # Scatter plot of petal length and petal width

# %%
plt.figure(figsize=(10,10))
plt.scatter(setosa['petal_length'],setosa['petal_width'],c='blue',label='Iris-setosa',marker='*')
plt.scatter(versicolor['petal_length'],versicolor['petal_width'],c='red',label='versicolor',marker='^')
plt.scatter(virginica['petal_length'],virginica['petal_width'],c='green',label='veirginica',marker='<')
plt.xlabel('petal_length')
plt.ylabel('petal_width')
plt.title('petal length vs petal width',fontsize=15)
plt.legend()

# %% [markdown]
# # Spliting the dataset

# %%
x=flower.drop(columns='species')
y=flower['species']

# %%
#let's see how data is distributed for every column
plt.figure(figsize=(20,20),facecolor='white')
plotnumber=1

for column in x:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.stripplot(y,x[column])
    plotnumber+=1
plt.tight_layout()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.4, random_state=1)

# %%
x_train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 11            4.8          3.4           1.6          0.2
# 113           5.7          2.5           5.0          2.0
# 123           6.3          2.7           4.9          1.8
# 12            4.8          3.0           1.4          0.1
# 2             4.7          3.2           1.3          0.2

# %%
x_test.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 14            5.8          4.0           1.2          0.2
# 98            5.1          2.5           3.0          1.1
# 75            6.6          3.0           4.4          1.4
# 16            5.4          3.9           1.3          0.4
# 131           7.9          3.8           6.4          2.0

# %%
print('x_train: ', len(x_train))
print('x_test: ', len(x_test))
print('y_train: ', len(y_train))
print('y_test: ', len(y_test))
# Out:
# x_train:  90
# x_test:  60
# y_train:  90
# y_test:  60

# %% [markdown]
# # Building models (Supervised Machine Learning Model)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
lr=LogisticRegression()
knn=KNeighborsClassifier()
svm=SVC()
nb=GaussianNB()
dt=DecisionTreeClassifier()
rf=RandomForestClassifier()

# %% [markdown]
# # Training and Evaluatin the Models

# %%
models=[lr,knn,svm,nb,dt,rf]
scores=[]

for model in models:
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    scores.append(accuracy_score(y_test,y_pred))
    print("accuracy of "+type(model).__name__+ " is " ,accuracy_score(y_test,y_pred)*100)
# Out:
# accuracy of LogisticRegression is  96.66666666666667
# accuracy of KNeighborsClassifier is  98.33333333333333
# accuracy of SVC is  98.33333333333333
# accuracy of GaussianNB is  95.0
# accuracy of DecisionTreeClassifier is  96.66666666666667
# accuracy of RandomForestClassifier is  96.66666666666667
